# %%
# !pip install requests beautifulsoup4
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup

url = "https://bonbanh.com/tp-hcm/oto-cu-da-qua-su-dung"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

# %%
cars = []

for item in soup.select(".car-item")[:3]:  # lấy 3 card đầu tiên
    img = item.select_one(".h-car-img")["src"]
    name = item.select_one("[itemprop=\"name\"]").get_text(strip=True)
    status = item.select_one(".cb1").get_text(strip=True)
    # desc = item.select_one(".car-desc").get_text(strip=True)
    # location = item.select_one(".car-location").get_text(strip=True)

    cars.append({
        "Ảnh": img,
        "Tên xe": name,
        "Tình trạng": status,
        # "Mô tả": desc,
        # "Địa điểm": location
    })

print(cars)
# Out:
# [{'Ảnh': 'https://s.bonbanh.com/uploads/users/812204/car/6360350/s_1753867489.827.jpg', 'Tên xe': 'Ford Ranger XLS 2.0L 4x2 AT - 2025', 'Tình trạng': 'Xe cũ2025'}, {'Ảnh': 'https://s.bonbanh.com/uploads/users/587237/car/6433314/s_1757988241.726.jpg', 'Tên xe': 'Toyota Fortuner 2.4G 4x2 MT - 2017', 'Tình trạng': 'Xe cũ2017'}, {'Ảnh': 'https://s.bonbanh.com/uploads/users/673061/car/6443334/s_1758530179.967.jpg', 'Tên xe': 'Lexus ES 350 - 2015', 'Tình trạng': 'Xe cũ2015'}]
